# %%
import pandas as pd

df = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")  # or your dataset name
df.head()
df.to_excel("output.xlsx", index=False)

# %%
cols = [
    'EnvironmentSatisfaction',
    'YearsAtCompany',
    'MonthlyIncome',
    'HourlyRate',
    'JobInvolvement',
    'JobSatisfaction'
]

desc = df[cols].describe()
print(desc)
# Out:
#        EnvironmentSatisfaction  YearsAtCompany  MonthlyIncome   HourlyRate  \
# count              1470.000000     1470.000000    1470.000000  1470.000000
# mean                  2.721769        7.008163    6502.931293    65.891156
# std                   1.093082        6.126525    4707.956783    20.329428
# min                   1.000000        0.000000    1009.000000    30.000000
# 25%                   2.000000        3.000000    2911.000000    48.000000
# 50%                   3.000000        5.000000    4919.000000    66.000000
# 75%                   4.000000        9.000000    8379.000000    83.750000
# max                   4.000000       40.000000   19999.000000   100.000000
#
#        JobInvolvement  JobSatisfaction
# count     1470.000000      1470.000000
# mean         2.729932         2.728571
# std          0.711561         1.102846
# min          1.000000         1.000000
# 25%          2.000000         2.000000
# 50%          3.000000         3.000000
# ...

# %%
print(df['JobRole'].value_counts())
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %%
print(df['OverTime'].value_counts())
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %%
grouped = df.groupby('JobRole')['JobSatisfaction'].mean()
print(grouped)
# Out:
# JobRole
# Healthcare Representative    2.786260
# Human Resources              2.557692
# Laboratory Technician        2.691120
# Manager                      2.705882
# Manufacturing Director       2.682759
# Research Director            2.700000
# Research Scientist           2.773973
# Sales Executive              2.754601
# Sales Representative         2.734940
# Name: JobSatisfaction, dtype: float64
