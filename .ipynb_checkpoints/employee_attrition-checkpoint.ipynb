# %% [markdown]
# # Study dataset - Employee Attrition

# %%
import pandas as pd
df_employee = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df_employee.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
daily_rates = df_employee['DailyRate'].head(100).to_numpy()
print(daily_rates)
# Out:
# [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945  852 1214  111  573
#  1153 1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120
#   682  489]

# %%
daily_rate_list = df_employee['DailyRate'][:20].tolist()

print(daily_rate_list)
# Out:
# [1102, 279, 1373, 1392, 591, 1005, 1324, 1358, 216, 1299, 809, 153, 670, 1346, 103, 1389, 334, 1123, 1219, 371]

# %%
df_employee.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
avg_daily_rate = df_employee.loc[df_employee['Attrition'] == 'Yes', 'DailyRate'].mean()
print(avg_daily_rate)
# Out:
# 750.3628691983122

# %%
df_select = df_employee[0:100][['DailyRate', 'Attrition', 'Age', 'Department', 'EducationField','JobRole', 'HourlyRate', 'MonthlyIncome', 'OverTime']]

# %%
len(df_select)
# Out:
# 100

# %%
df_select.shape
# Out:
# (100, 10)

# %%
df_select.head()
# Out:
#    DailyRate Attrition  Age              Department EducationField  \
# 0       1102       Yes   41                   Sales  Life Sciences
# 1        279        No   49  Research & Development  Life Sciences
# 2       1373       Yes   37  Research & Development          Other
# 3       1392        No   33  Research & Development  Life Sciences
# 4        591        No   27  Research & Development        Medical
#
#                  JobRole  HourlyRate  MonthlyIncome OverTime  GoodSalary
# 0        Sales Executive          94           5993      Yes        True
# 1     Research Scientist          61           5130       No       False
# 2  Laboratory Technician          92           2090      Yes        True
# 3     Research Scientist          56           2909      Yes        True
# 4  Laboratory Technician          40           3468       No       False

# %%
df_select[df_select['DailyRate'] > 1000][['DailyRate']]
# Out:
#     DailyRate
# 0        1102
# 2        1373
# 3        1392
# 5        1005
# 6        1324
# 7        1358
# 9        1299
# 13       1346
# 15       1389
# 17       1123
# 18       1219
# 21       1218
# 25       1282
# 26       1125
# 31       1459
# 35       1273
# 39       1141
# 41       1240
# 42       1357
# 45       1360
# 46       1065
# 48       1211
# 49       1229
# 51       1434
# 52       1488
# 53       1097
# 54       1443
# 57       1142
# 59       1115
# 63       1435
# 64       1223
# 66       1195
# 67       1339
# 70       1225
# 71       1328
# 72       1082
# 81       1214
# 84       1153
# 85       1400
# 92       1334
# 94       1093
# 95       1217
# 96       1353

# %%
good_salary = pd.Series(df_select['DailyRate'] > 1000)
df_select = pd.concat([df_select, good_salary.rename('GoodSalary')], axis=1)

# %%
df_select['DailyRate'].value_counts()
# Out:
# DailyRate
# 852     0.02
# 1102    0.01
# 279     0.01
# 1373    0.01
# 1392    0.01
#         ...
# 1217    0.01
# 1353    0.01
# 120     0.01
# 682     0.01
# 489     0.01
# Name: proportion, Length: 99, dtype: float64

# %%
good_salary
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4     False
#       ...
# 95     True
# 96     True
# 97    False
# 98    False
# 99    False
# Name: DailyRate, Length: 100, dtype: bool
